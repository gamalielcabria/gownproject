# %% [markdown]
# # Data analysis of image labels using OpenAI API
#
# This is the analysis and wrangling of data dgenerated by the scripts **main.py** of the OpenAI API

# %%
import os

folder_path = '/home/glbcabria/Workbench/GOWN_Data/Photos/GOWN_Bottles/Renamed'
